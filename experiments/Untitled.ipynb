# %%
from pymongo.mongo_client import MongoClient
import urllib.parse

# Encode the username and password
username = urllib.parse.quote_plus("aibi10")
password = urllib.parse.quote_plus("QWertyu1234@")

# Create the MongoDB connection URI
uri = f"mongodb+srv://{username}:{password}@cluster0.2gn2i.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Connect to MongoDB
client = MongoClient(uri)

# %%
database = client["youtubecommunity"]

# %%
collection = database["sessions"]

# %%
data = {
    "coursename":"generative ai",
    "instructor":"abhishek",
    "mode": "online",
    
}

# %%
collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('66f253aad8699f8ebb4b3399'), acknowledged=True)

# %%
all_record = collection.find()

# %%
for record in all_record:
    print(record)
# Out:
# {'_id': ObjectId('66efed46b74d01970b7900e9'), 'coursename': 'generative ai', 'instructor': 'abhishek', 'mode': 'online'}
# {'_id': ObjectId('66f004d7b74d01970b7900ea'), 'coursename': 'natural language processing', 'instructor': 'abhishek', 'mode': 'online'}
# {'_id': ObjectId('66f004d7b74d01970b7900eb'), 'coursename': 'mlops', 'instructor': 'abhishek', 'mode': 'offline'}
# {'_id': ObjectId('66f253aad8699f8ebb4b3399'), 'coursename': 'generative ai', 'instructor': 'abhishek', 'mode': 'online'}

# %%
collection.insert_many(
    [
       {
    "coursename":"natural language processing",
    "instructor":"abhishek",
    "mode": "online",
    
},
        {
    "coursename":"mlops",
    "instructor":"abhishek",
    "mode": "offline",
    
}
    ]
)
# Out:
# InsertManyResult([ObjectId('66f253b7d8699f8ebb4b339a'), ObjectId('66f253b7d8699f8ebb4b339b')], acknowledged=True)

# %%
class mongodb_operation:
    
    def __init__(self, client_url: str, database_name: str, collection_name: str=None):
        self.client_url = client_url
        self.database_name = database_name
        self.collection_name = collection_name
        
    def create_client(self):
        client = MongoClient(self.client_url)
        return client
    
    def create_database(self):
        client = self.create_client()
        database = client[self.database_name]
        return database
    
    def create_collection(self):
        database = self.create_database()
        collection = database[self.collection_name]
        
    
    def isnert_record(self):
        pass
    
    def bulk_insert(self):
        pass

# %%
# !pip install mongodbautomationaibi==0.0.4
# Out:
# Requirement already satisfied: mongodbautomationaibi==0.0.4 in c:\users\abhishek\anaconda3\lib\site-packages (0.0.4)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# absl-py                       2.1.0
# accelerate                    0.32.1
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.5
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# anaconda-anon-usage           0.4.2
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.1
# anaconda-cloud-auth           0.1.3
# anaconda-navigator            2.5.0
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# arabert                       1.0.1
# arabic-reshaper               3.0.0
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# attrs                         23.2.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.11.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.12.2
# binaryornot                   0.4.4
# bitsandbytes                  0.43.1
# black                         0.0
# bleach                        4.1.0
# blosc2                        2.7.1
# bokeh                         3.2.1
# boltons                       23.0.0
# botocore                      1.29.76
# Bottleneck                    1.3.5
# breadability                  0.1.20
# Brotli                        1.1.0
# brotlipy                      0.7.0
# bs4                           0.0.2
# cachetools                    5.5.0
# category-encoders             2.6.3
# certifi                       2023.7.22
# cffi                          1.15.1
# chardet                       5.2.0
# charset-normalizer            2.0.4
# click                         8.0.4
# cloudpickle                   2.2.1
# clyent                        1.2.1
# colorama                      0.4.6
# colorcet                      3.0.1
# comm                          0.1.2
# conda                         23.7.4
# conda-build                   3.26.1
# conda-content-trust           0.2.0
# conda_index                   0.3.0
# conda-libmamba-solver         23.7.0
# conda-pack                    0.6.0
# conda-package-handling        2.2.0
# conda_package_streaming       0.9.0
# conda-repo-cli                1.0.75
# conda-token                   0.4.0
# conda-verify                  3.4.2
# configparser                  7.0.0
# constantly                    15.1.0
# contourpy                     1.0.5
# cookiecutter                  1.7.3
# coverage                      7.4.4
# coveralls                     4.0.0
# cryptography                  41.0.3
# cssselect                     1.1.0
# cycler                        0.11.0
# Cython                        3.0.11
# cytoolz                       0.12.0
# daal4py                       2023.1.1
# dask                          2023.6.0
# dataclasses-json              0.6.7
# datashader                    0.15.2
# datashape                     0.5.4
# dateparser                    1.2.0
# debugpy                       1.6.7
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# dill                          0.3.6
# distlib                       0.3.8
# distributed                   2023.6.0
# distro                        1.9.0
# dm-tree                       0.1.8
# dnspython                     2.6.1
# docopt                        0.6.2
# docstring-to-markdown         0.11
# docutils                      0.18.1
# emoji                         1.4.2
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# executing                     0.8.3
# Farasa                        0.0.1
# farasapy                      0.0.14
# fastjsonschema                2.16.2
# filelock                      3.16.1
# flake8                        6.0.0
# Flask                         2.2.2
# flatbuffers                   24.3.25
# fonttools                     4.25.0
# frozenlist                    1.3.3
# fsspec                        2023.4.0
# fst-pso                       1.8.1
# future                        0.18.3
# FuzzyTM                       2.0.9
# gast                          0.5.4
# gensim                        4.3.0
# genson                        1.2.2
# geographiclib                 2.0
# geopy                         2.4.1
# glob2                         0.7
# google-pasta                  0.2.0
# greenlet                      2.0.1
# grpcio                        1.62.1
# h11                           0.9.0
# h2                            3.2.0
# h5py                          3.10.0
# HeapDict                      1.0.1
# holoviews                     1.17.1
# hpack                         3.0.0
# hstspreload                   2024.7.1
# httmock                       1.4.0
# httpcore                      0.9.1
# httpx                         0.13.3
# huggingface-hub               0.24.7
# hvplot                        0.8.4
# hyperframe                    5.2.0
# hyperlink                     21.0.0
# hypothesis                    6.100.2
# idna                          2.10
# imagecodecs                   2023.1.23
# imageio                       2.26.0
# imagesize                     1.4.1
# imbalanced-learn              0.10.1
# importlib-metadata            6.0.0
# incremental                   21.3.0
# inflate64                     1.0.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.8
# intervaltree                  3.1.0
# ipykernel                     6.25.0
# ipython                       8.15.0
# ipython-genutils              0.2.0
# ipywidgets                    8.0.4
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jaraco.classes                3.2.1
# jedi                          0.18.1
# jellyfish                     1.0.1
# Jinja2                        3.1.2
# jinja2-time                   0.2.0
# jiter                         0.5.0
# jmespath                      0.10.0
# joblib                        1.2.0
# json5                         0.9.6
# jsonpatch                     1.33
# jsonpointer                   2.1
# jsonschema                    4.17.3
# jupyter                       1.0.0
# jupyter_client                7.4.9
# jupyter-console               6.6.3
# jupyter_core                  5.3.0
# jupyter-events                0.6.3
# jupyter-server                1.23.4
# jupyter_server_fileid         0.9.0
# jupyter_server_ydoc           0.8.0
# jupyter-ydoc                  0.2.4
# jupyterlab                    3.6.3
# jupyterlab-pygments           0.1.2
# jupyterlab_server             2.22.0
# jupyterlab-widgets            3.0.5
# kaleido                       0.2.1
# keras                         3.4.1
# keyring                       23.13.1
# kiwisolver                    1.4.4
# langchain                     0.2.7
# langchain-community           0.2.7
# langchain-core                0.2.38
# langchain-openai              0.1.23
# langchain-text-splitters      0.2.2
# langsmith                     0.1.84
# lazy_loader                   0.2
# lazy-object-proxy             1.6.0
# libarchive-c                  2.9
# libclang                      16.0.6
# libmambapy                    1.5.1
# lightgbm                      4.3.0
# linkify-it-py                 2.0.0
# llvmlite                      0.40.0
# lmdb                          1.4.1
# locket                        1.0.0
# lxml                          4.9.3
# lz4                           4.3.2
# Markdown                      3.4.1
# markdown-it-py                2.2.0
# MarkupSafe                    2.1.1
# marshmallow                   3.21.3
# matplotlib                    3.7.2
# matplotlib-inline             0.1.6
# mccabe                        0.7.0
# mdit-py-plugins               0.3.0
# mdurl                         0.1.0
# menuinst                      1.4.19
# miniful                       0.0.6
# mistune                       0.8.4
# mkl-fft                       1.3.8
# mkl-random                    1.2.4
# mkl-service                   2.4.0
# ml-dtypes                     0.3.2
# mock                          5.1.0
# mongodbautomationaibi         0.0.4
# more-itertools                8.12.0
# MouseInfo                     0.1.3
# mpmath                        1.3.0
# msgpack                       1.0.3
# mtranslate                    1.8
# multidict                     6.0.2
# multipledispatch              0.6.0
# multiprocess                  0.70.14
# multivolumefile               0.2.3
# munkres                       1.1.4
# mypy-extensions               1.0.0
# namex                         0.0.7
# navigator-updater             0.4.0
# nbclassic                     0.5.5
# nbclient                      0.5.13
# nbconvert                     6.5.4
# nbformat                      5.9.2
# ndindex                       1.8
# nest-asyncio                  1.5.6
# networkx                      3.1
# nltk                          3.8.1
# notebook                      6.5.4
# notebook_shim                 0.2.2
# numba                         0.57.1
# numexpr                       2.8.4
# numpy                         1.24.4
# numpydoc                      1.5.0
# openai                        1.43.0
# opencv-python                 4.9.0.80
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# optree                        0.12.1
# orjson                        3.10.6
# packaging                     24.1
# pandas                        1.5.3
# pandocfilters                 1.5.0
# panel                         1.2.3
# param                         1.13.0
# paramiko                      2.8.1
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.4.0
# pathlib                       1.0.1
# pathspec                      0.10.3
# patsy                         0.5.3
# pep8                          1.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.4.0
# pip                           24.0
# pkce                          1.0.3
# pkginfo                       1.9.6
# platformdirs                  4.3.6
# plotly                        5.9.0
# pluggy                        1.5.0
# ply                           3.11
# portalocker                   2.10.1
# poyo                          0.5.0
# prometheus-api-client         0.5.4
# prometheus-client             0.14.1
# prompt-toolkit                3.0.36
# Protego                       0.1.16
# protobuf                      4.25.3
# psutil                        5.9.0
# psycopg2                      2.9.9
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py-cpuinfo                    8.0.0
# py7zr                         0.21.1
# PyArabic                      0.6.15
# pyarrow                       17.0.0
# pyarrow-hotfix                0.6
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# PyAutoGUI                     0.9.54
# pybcj                         1.0.2
# pycodestyle                   2.10.0
# pycosat                       0.6.4
# pycountry                     24.6.1
# pycparser                     2.21
# pycryptodomex                 3.20.0
# pyct                          0.5.0
# pycurl                        7.45.2
# pydantic                      1.10.8
# PyDispatcher                  2.0.5
# pydocstyle                    6.3.0
# pyerfa                        2.0.0
# pyflakes                      3.0.1
# pyFUME                        0.3.4
# PyGetWindow                   0.0.9
# Pygments                      2.15.1
# PyJWT                         2.4.0
# pylint                        2.16.2
# pylint-venv                   2.3.0
# pyls-spyder                   0.4.0
# pymongo                       4.9.1
# PyMsgBox                      1.0.9
# PyMuPDF                       1.24.10
# PyMuPDFb                      1.24.10
# PyNaCl                        1.5.0
# pyodbc                        4.0.34
# pyOpenSSL                     23.2.0
# pyparsing                     3.0.9
# pypdf                         4.3.1
# pyperclip                     1.8.2
# pyppmd                        1.1.0
# pyproject-api                 1.8.0
# PyQt5                         5.15.7
# PyQt5-sip                     12.11.0
# PyQtWebEngine                 5.15.4
# PyRect                        0.2.0
# pyrsistent                    0.18.0
# PyScreeze                     0.1.30
# PySocks                       1.7.1
# pytest                        7.4.0
# pytest-cov                    5.0.0
# python-dateutil               2.8.2
# python-dotenv                 0.21.0
# python-json-logger            2.0.7
# python-lsp-black              1.2.1
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.7.2
# python-slugify                5.0.2
# python-snappy                 0.6.1
# pytoolconfig                  1.2.5
# pytweening                    1.0.7
# pytz                          2023.3.post1
# pyviz-comms                   2.3.0
# PyWavelets                    1.4.1
# pywin32                       305.1
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.10
# PyYAML                        6.0.1
# pyzmq                         23.2.0
# pyzstd                        0.16.1
# QDarkStyle                    3.0.2
# qstylizer                     0.2.2
# QtAwesome                     1.2.2
# qtconsole                     5.4.2
# QtPy                          2.2.0
# queuelib                      1.5.0
# regex                         2022.7.9
# reportlab                     4.2.0
# requests                      2.32.3
# requests-file                 1.5.1
# requests-mock                 1.12.1
# requests-toolbelt             1.0.0
# responses                     0.13.3
# rfc3339-validator             0.1.4
# rfc3986                       1.5.0
# rfc3986-validator             0.1.1
# rich                          13.7.1
# rope                          1.7.0
# rouge-score                   0.1.2
# Rtree                         1.0.1
# ruamel.yaml                   0.17.21
# ruamel-yaml-conda             0.17.21
# s3fs                          2023.4.0
# sacrebleu                     2.4.2
# safetensors                   0.4.3
# scikit-image                  0.20.0
# scikit-learn                  1.4.1.post1
# scikit-learn-intelex          20230426.121932
# scipy                         1.10.1
# Scrapy                        2.8.0
# seaborn                       0.12.2
# Send2Trash                    1.8.0
# sentencepiece                 0.2.0
# service-identity              18.1.0
# setuptools                    68.0.0
# simpful                       2.12.0
# simplejson                    3.19.2
# sip                           6.6.2
# six                           1.16.0
# smart-open                    5.2.1
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# soupsieve                     2.4
# Sphinx                        5.0.2
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.4.3
# spyder-kernels                2.4.4
# SQLAlchemy                    1.4.39
# stack-data                    0.2.0
# statsmodels                   0.14.0
# sumy                          0.11.0
# sympy                         1.11.1
# tableauhyperapi               0.0.18618
# tables                        3.8.0
# tabpy                         2.9.0
# tabulate                      0.8.10
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.2.2
# tensorboard                   2.17.0
# tensorboard-data-server       0.7.2
# tensorflow                    2.17.0
# tensorflow-intel              2.17.0
# tensorflow-io-gcs-filesystem  0.31.0
# termcolor                     2.4.0
# terminado                     0.17.1
# text-unidecode                1.3
# textblob                      0.18.0.post0
# textdistance                  4.2.1
# texttable                     1.7.0
# tf_keras                      2.17.0
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tifffile                      2023.4.12
# tiktoken                      0.7.0
# tinycss2                      1.2.1
# tldextract                    3.2.0
# tokenizers                    0.19.1
# toml                          0.10.2
# tomlkit                       0.11.1
# toolz                         0.12.0
# torch                         2.4.1
# tornado                       6.3.2
# tox                           4.20.0
# tqdm                          4.66.5
# traitlets                     5.7.1
# transformers                  4.42.3
# Twisted                       22.10.0
# twisted-iocpsupport           1.0.2
# typing_extensions             4.11.0
# typing-inspect                0.9.0
# tzdata                        2023.3
# tzlocal                       5.2
# uc-micro-py                   1.0.1
# ujson                         5.4.0
# Unidecode                     1.2.0
# urllib3                       1.26.16
# virtualenv                    20.26.5
# w3lib                         1.21.0
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# Werkzeug                      2.2.3
# whatthepatch                  1.0.2
# wheel                         0.38.4
# widgetsnbextension            4.0.5
# wikipedia                     1.4.0
# win-inet-pton                 1.1.0
# wrapt                         1.14.1
# xarray                        2023.6.0
# xgboost                       2.0.3
# xlrd                          2.0.1
# xlwings                       0.29.1
# xxhash                        2.0.2
# xyzservices                   2022.9.0
# y-py                          0.5.9
# yapf                          0.31.0
# yarl                          1.8.1
# ypy-websocket                 0.8.2
# zict                          2.2.0
# zipp                          3.11.0
# zope.interface                5.4.0
# zstandard                     0.19.0
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mongodbautomationaibi

# %%
mongo = mongodbautomationaibi.mongo_operation(uri, "abc", "xyz")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 mongo = mongodbautomationaibi.mongo_operation(uri, "abc", "xyz")
#
# AttributeError: module 'mongodbautomationaibi' has no attribute 'mongo_operation'
